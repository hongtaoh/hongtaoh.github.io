# %% [markdown]
# ---
#
# title: Julia Try
# date: 2023-02-26
# author: Hongtao Hao
# slug: julia
# draft: false
# toc: true
# tags: Math
#
# ---

# %%
using Plots

# http://mth229.github.io/graphing.html

f(x) = - x^2 + 5x

plot(f, 0, 5,
    label=""
)

# savefig("juliaplots/p1.png")

# %% [markdown]
# <!-- ![](juliaplots/p1.png) -->
